# %% [markdown]
# <a href="https://colab.research.google.com/github/subaruosawa/last-piriod/blob/master/github_searchAPI.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import json
import requests

# %%
with open("/content/drive/My Drive/channelId.json")as f:
  channelId = json.load(f)

# %%
number = range(106)
num_chId = dict(zip(number,channelId))

# %%
nextPageToken0=[];nextPageToken1=[];nextPageToken2=[];nextPageToken3=[];nextPageToken4=[];nextPageToken5=[]
s_data=[];s_data_nPT0=[];s_data_nPT1=[];s_data_nPT2=[];s_data_nPT3=[];s_data_nPT4=[]
nextPageToken_list = [
nextPageToken0,nextPageToken1,nextPageToken2,nextPageToken3,nextPageToken4,nextPageToken5
]
s_data_list = [
s_data,s_data_nPT0,s_data_nPT1,s_data_nPT2,s_data_nPT3,s_data_nPT4   
]

# %%
videoId = [[]*n for n in range(106)]

# %%
for num,chid in num_chId.items():
  n = 0
  for i in nextPageToken_list:
    i = []
  for i in s_data_list:
    i = []
  print("liver_No."+str(num))

  options = {
      "key": "AIzaSyCtzF8YJWJK4wiHT5-2_eDpQFFtM9qha3g",
      "part": "id",
      "maxResults":50,
      "order":"date",
      "type":"video",
      "channelId":chid,
      "publishedAfter": "2020-09-01T09:00:00Z",
      "publishedBefore": "2020-10-01T08:59:59Z",
      "eventType":"completed",
      "pageToken":""
      }
  r = requests.get('https://www.googleapis.com/youtube/v3/search', params=options)
  s_data_list[n] = r.json()

  if "items" in s_data_list[n]:
    if s_data_list[n]["items"]:
      for vid in s_data_list[n]["items"]:
        videoId[num].append(vid["id"]["videoId"])
    elif not s_data_list[n]["items"]:
      print("no_items in s_data")
      print(s_data_list[n])
  elif "error" in s_data_list[n]:
    print("error in s_data")
    print(s_data_list[n])
  else:
    print("what?s_data")
    print(s_data_list[n])

  if "nextPageToken" in s_data_list[n]:
    nextPageToken_list[n] = s_data_list[n]["nextPageToken"]
  elif not "nextPageToken" in s_data_list[n]:
    print("no_nPT in s_data")

###############################################################################
  if nextPageToken_list[n]:
    options = {
      "key": "AIzaSyCtzF8YJWJK4wiHT5-2_eDpQFFtM9qha3g",
      "part": "id",
      "maxResults":50,
      "order":"date",
      "type":"video",
      "channelId":chid,
      "publishedAfter": "2020-09-01T09:00:00Z",
      "publishedBefore": "2020-10-01T08:59:59Z",
      "eventType":"completed",
      "pageToken":nextPageToken_list[n]
      }
    n += 1
    r = requests.get('https://www.googleapis.com/youtube/v3/search', params=options)
    s_data_list[n] = r.json()

    if "items" in s_data_list[n]:
      if s_data_list[n]["items"]:
        for vid in s_data_list[n]["items"]:
          videoId[num].append(vid["id"]["videoId"])
      elif not s_data_list[n]["items"]:
        print("no_items in s_data_nPT"+str(n-1))
        print(s_data_list[n])
    elif "error" in s_data_list[n]:
      print("error in s_data_nPT"+str(n-1))
      print(s_data_list[n])
    else:
      print("what?s_data_nPT"+str(n-1))
      print(s_data_list[n])

    if "nextPageToken" in s_data_list[n]:
      nextPageToken_list[n] = s_data_list[n]["nextPageToken"]
    elif not "nextPageToken" in s_data_list[n]:
      print("no_nPT in s_data_nPT"+str(n-1))

###############################################################################
  if nextPageToken_list[n]:
    options = {
      "key": "AIzaSyCtzF8YJWJK4wiHT5-2_eDpQFFtM9qha3g",
      "part": "id",
      "maxResults":50,
      "order":"date",
      "type":"video",
      "channelId":chid,
      "publishedAfter": "2020-09-01T09:00:00Z",
      "publishedBefore": "2020-10-01T08:59:59Z",
      "eventType":"completed",
      "pageToken":nextPageToken_list[n]
      }
    n += 1
    r = requests.get('https://www.googleapis.com/youtube/v3/search', params=options)
    s_data_list[n] = r.json()

    if "items" in s_data_list[n]:
      if s_data_list[n]["items"]:
        for vid in s_data_list[n]["items"]:
          videoId[num].append(vid["id"]["videoId"])
      elif not s_data_list[n]["items"]:
        print("no_items in s_data_nPT"+str(n-1))
        print(s_data_list[n])
    elif "error" in s_data_list[n]:
      print("error in s_data_nPT"+str(n-1))
      print(s_data_list[n])
    else:
      print("what?s_data_nPT"+str(n-1))
      print(s_data_list[n])

    if "nextPageToken" in s_data_list[n]:
      nextPageToken_list[n] = s_data_list[n]["nextPageToken"]
    elif not "nextPageToken" in s_data_list[n]:
      print("no_nPT in s_data_nPT"+str(n-1))

###############################################################################
  if nextPageToken_list[n]:
    options = {
      "key": "AIzaSyCtzF8YJWJK4wiHT5-2_eDpQFFtM9qha3g",
      "part": "id",
      "maxResults":50,
      "order":"date",
      "type":"video",
      "channelId":chid,
      "publishedAfter": "2020-09-01T09:00:00Z",
      "publishedBefore": "2020-10-01T08:59:59Z",
      "eventType":"completed",
      "pageToken":nextPageToken_list[n]
      }
    n += 1
    r = requests.get('https://www.googleapis.com/youtube/v3/search', params=options)
    s_data_list[n] = r.json()

    if "items" in s_data_list[n]:
      if s_data_list[n]["items"]:
        for vid in s_data_list[n]["items"]:
          videoId[num].append(vid["id"]["videoId"])
      elif not s_data_list[n]["items"]:
        print("no_items in s_data_nPT"+str(n-1))
        print(s_data_list[n])
    elif "error" in s_data_list[n]:
      print("error in s_data_nPT"+str(n-1))
      print(s_data_list[n])
    else:
      print("what?s_data_nPT"+str(n-1))
      print(s_data_list[n])

    if "nextPageToken" in s_data_list[n]:
      nextPageToken_list[n] = s_data_list[n]["nextPageToken"]
    elif not "nextPageToken" in s_data_list[n]:
      print("no_nPT in s_data_nPT"+str(n-1))

###############################################################################
  if nextPageToken_list[n]:
    options = {
      "key": "AIzaSyCtzF8YJWJK4wiHT5-2_eDpQFFtM9qha3g",
      "part": "id",
      "maxResults":50,
      "order":"date",
      "type":"video",
      "channelId":chid,
      "publishedAfter": "2020-09-01T09:00:00Z",
      "publishedBefore": "2020-10-01T08:59:59Z",
      "eventType":"completed",
      "pageToken":nextPageToken_list[n]
      }
    n += 1
    r = requests.get('https://www.googleapis.com/youtube/v3/search', params=options)
    s_data_list[n] = r.json()

    if "items" in s_data_list[n]:
      if s_data_list[n]["items"]:
        for vid in s_data_list[n]["items"]:
          videoId[num].append(vid["id"]["videoId"])
      elif not s_data_list[n]["items"]:
        print("no_items in s_data_nPT"+str(n-1))
        print(s_data_list[n])
    elif "error" in s_data_list[n]:
      print("error in s_data_nPT"+str(n-1))
      print(s_data_list[n])
    else:
      print("what?s_data_nPT"+str(n-1))
      print(s_data_list[n])

    if "nextPageToken" in s_data_list[n]:
      nextPageToken_list[n] = s_data_list[n]["nextPageToken"]
    elif not "nextPageToken" in s_data_list[n]:
      print("no_nPT in s_data_nPT"+str(n-1))

###############################################################################
  if nextPageToken_list[n]:
    options = {
      "key": "AIzaSyCtzF8YJWJK4wiHT5-2_eDpQFFtM9qha3g",
      "part": "id",
      "maxResults":50,
      "order":"date",
      "type":"video",
      "channelId":chid,
      "publishedAfter": "2020-09-01T09:00:00Z",
      "publishedBefore": "2020-10-01T08:59:59Z",
      "eventType":"completed",
      "pageToken":nextPageToken_list[n]
      }
    n += 1
    r = requests.get('https://www.googleapis.com/youtube/v3/search', params=options)
    s_data_list[n] = r.json()

    if "items" in s_data_list[n]:
      if s_data_list[n]["items"]:
        for vid in s_data_list[n]["items"]:
          videoId[num].append(vid["id"]["videoId"])
      elif not s_data_list[n]["items"]:
        print("no_items in s_data_nPT"+str(n-1))
        print(s_data_list[n])
    elif "error" in s_data_list[n]:
      print("error in s_data_nPT"+str(n-1))
      print(s_data_list[n])
    else:
      print("what?s_data_nPT"+str(n-1))
      print(s_data_list[n])

    if "nextPageToken" in s_data_list[n]:
      nextPageToken_list[n] = s_data_list[n]["nextPageToken"]
    elif not "nextPageToken" in s_data_list[n]:
      print("no_nPT in s_data_nPT"+str(n-1))

# %%
with open("videoId.json","w")as f:
  json.dump(videoId,f,indent=4,ensure_ascii=False)
